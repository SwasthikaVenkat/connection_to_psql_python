# %%
# !pip install ipython-sql
# !pip install sqlalchemy 
#library that facilitates the communication between Python programs and databases.
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install psycopg2
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext sql 
#ipython-sql is activated in your notebook

# %%
from sqlalchemy import create_engine

# %%
# %sql postgresql://postgres:your_password@localhost/postgres

# %%
engine = create_engine('postgresql://postgres:your_password@localhost/postgres')

# %%
# %%sql
# select * from employees;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 474 rows affected.
# [(1.0, 'Male', datetime.date(1952, 2, 3), 15, 'Manager', 57000, 27000, 98, 144, 'No'),
#  (2.0, 'Male', datetime.date(1958, 5, 23), 16, 'Clerical', 40200, 18750, 98, 36, 'No'),
#  (3.0, 'Female', datetime.date(1929, 7, 26), 12, 'Clerical', 21450, 12000, 98, 381, 'No'),
#  (4.0, 'Female', datetime.date(1947, 4, 15), 8, 'Clerical', 21900, 13200, 98, 190, 'No'),
#  (5.0, 'Male', datetime.date(1955, 2, 9), 15, 'Clerical', 45000, 21000, 98, 138, 'No'),
#  (6.0, 'Male', datetime.date(1958, 8, 22), 15, 'Clerical', 32100, 13500, 98, 67, 'No'),
#  (7.0, 'Male', datetime.date(1956, 4, 26), 15, 'Clerical', 36000, 18750, 98, 114, 'No'),
#  (8.0, 'Female', datetime.date(1966, 5, 6), 12, 'Clerical', 21900, 9750, 98, 233, 'No'),
#  (9.0, 'Female', datetime.date(1946, 1, 23), 15, 'Clerical', 27900, 12750, 98, 115, 'No'),
#  (10.0, 'Female', datetime.date(1946, 2, 13), 12, 'Clerical', 24000, 13500, 98, 244, 'No'),
# ...

# %%
# %%sql
# select MAX(salary) from employees;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(135000,)]

# %%
# %%sql
# select MIN(salary) from employees;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(15750,)]

# %%
# %%sql
# select AVG(salary) from employees;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(Decimal('34419.567510548523'),)]

# %%
# %sql select gender, salary from employees where  salary = (select max(salary) from employees);
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [('Male', 135000)]
